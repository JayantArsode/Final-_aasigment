# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# <h1> My Jupyter Notebook on IBM Watson Studio <h1>

# %% [markdown]
# **Jayant Reshim Arsode**<br>My current occupation is Student.

# %% [markdown]
# *I am interested in data science because of my curiosity about how machine solve problems like humans and how the this field of data science is growing at exponential rate also i am think it is one of the most existing and interesting jobs*

# %% [markdown]
# <h3> My code simply squares all list element and print them <h3>

# %%
def squraed_of_list_given(list1):
    print(list(map(lambda x: x**2, list1)))

# %%
squraed_of_list_given([1, 2, 3, 4, 5])
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# > Hello this Blocked Quote

# %% [markdown]
# <h4> Numbered List </h4>
# <ol>
#   <li>First item</li>
#   <li>Second item</li>
#   <li>Third item</li>
#   <li>Fourth item</li>
# </ol>
# <h4> Bulleted List </h4>
# <ul>
#   <li>First item</li>
#   <li>Second item</li>
#   <li>Third item</li>
#   <li>Fourth item</li>
# </ul>

# %% [markdown]
# My favorite search engine is [Google](https://www.google.co.in/).

# %% [markdown]
# ![duck.jpg](attachment:3f3fd85f-ec2a-452e-b0af-66b9923f4b64.jpg)

# %% [markdown]
# Col1 |Col2 |Col3
# -----|-----|-----
# Data1|Data2|Data3
# Data1|Data2|Data3
# Data1|Data2|Data3
# Data1|Data2|Data3
